# %%
import pandas as pd
import numpy as np

# %%
def lista_tiene_nans(lista):
    #lista_str = [str(i) for i in lista]
    return all(elem in ['nan', None, 'None',np.nan] for elem in lista)

# %%
excel_file = '../videos_maquetados.xlsx'


xls = pd.ExcelFile(excel_file)

sheet_names = xls.sheet_names

codigo_asignatura_s = []
url_s = []
sesion_s = []
intancia = 0
codigo_videos_dict = {} 
for sheet_name in sheet_names:
    df = pd.read_excel(excel_file, sheet_name=sheet_name)
    if 'Ejercicio' in df.columns:
        if lista_tiene_nans(sesion_practica):
            sesion = list(df['Sesión'])
            url = list(df['Código'])
            codigo_asignatura = [sheet_name for _ in range(len(sesion))]
            for i in range(len(codigo_asignatura)):
                codigo_videos_dict[intancia] = {'codigo_asignatura': codigo_asignatura[i],'url': url[i],'sesion':sesion[i]} 
                intancia += 1
        else:
            sesion_teorica = list(df['Sesión'])
            codigo_teorica = list(df['Código'])
            sesion_practica = list(df['Ejercicio'])
            codigo_practica = list(df['Código.1'])
            sesion = sesion_teorica + sesion_practica
            url = codigo_teorica + codigo_practica
            codigo_asignatura = [sheet_name for _ in range(len(url))]
            for i in range(len(codigo_asignatura)):
                codigo_videos_dict[intancia] = {'codigo_asignatura': codigo_asignatura[i],'url': url[i],'sesion':sesion[i]} 
                intancia += 1
    else:
        sesion = list(df['Sesión'])
        url = list(df['Código'])
        codigo_asignatura = [sheet_name for _ in range(len(sesion))]
        for i in range(len(codigo_asignatura)):
                codigo_videos_dict[intancia] = {'codigo_asignatura': codigo_asignatura[i],'url': url[i],'sesion':sesion[i]} 
                intancia += 1

# %%
codigo_videos = pd.DataFrame(codigo_videos_dict).T

# %%
codigo_videos_sin_nans = codigo_videos.dropna(subset=['url'])

# %%
codigo_videos_sin_nans
# Out:
#     codigo_asignatura       url  \
# 0                 M11  BJG5Dhic
# 1                 M11  4hh99HjI
# 2                 M11  j6H4FGDh
# 3                 M11  6JejH53h
# 4                 M11  jE6690jf
# ..                ...       ...
# 324               M53  3A3470Aj
# 325               M53  FcG1ieDg
# 326               M53  a3aGfCI1
# 327               M53  D87aga0h
# 328               M53  iB4fJ2He
#
#                                                 sesion
# 0                        M11 Fundamentos del Marketing
# 1                         1. Introducción al marketing
# 2                                 2. Plan de marketing
# 3    3.Marketing mix - Producto (user experience) y...
# 4             4. Marketing mix - Precio y comunicación
# ..                                                 ...
# 324  2. Aproximación legal a la normativa de protec...
# 325  3. Aproximación legal a la normativa de protec...
# 326      4. Aproximación legal ala Data Governance Act
# 327  5. Aproximación legal al Reglamento de Goberna...
# 328  6. Aproximación legal al ReglamentoEuropeo de ...
#
# [240 rows x 3 columns]
